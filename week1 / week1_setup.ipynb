# %% [markdown]
# <a href="https://colab.research.google.com/github/brandy99swords/AIML2013_CV/blob/main/week1%20/%20week1_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, AIML 2003!")
# Out:
# Hello, AIML 2003!

# %%
# !pip install google-genai

# %%
# !pip install google-genai -q

from google.colab import userdata
from google import genai

client = genai.Client(api_key=userdata.get('GEMINI_API_KEY'))

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="Say hello to AIML 2003!"
)
print(response.text)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# /tmp/ipykernel_9290/1910304704.py in <cell line: 0>()
#       6 client = genai.Client(api_key=userdata.get('GEMINI_API_KEY'))
#       7
# ----> 8 response = client.models.generate_content(
#       9     model="gemini-2.5-flash",
#      10     contents="Say hello to AIML 2003!"
#
# /usr/local/lib/python3.12/dist-packages/google/genai/models.py in generate_content(self, model, contents, config)
#    5707     while remaining_remote_calls_afc > 0:
#    5708       i += 1
# -> 5709       response = self._generate_content(
#    5710           model=model, contents=contents, config=parsed_config
#    5711       )
#
# /usr/local/lib/python3.12/dist-packages/google/genai/models.py in _generate_content(self, model, contents, config)
#    4369     request_dict = _common.encode_unserializable_types(request_dict)
#    4370
# ...

# %% [markdown]
# I attempted gemini-2.5-flash-lite, gemini-2.5-flash, gemini-2.5-flash-exp, gemini-2.0-flash-exp, and gemini-flash-latest
#
# I setup 2 projects, 1 that was set at tier 1 and 1 that was set at the free tier.
#
# I verified billing.
#
# Per Gemini, this is because I have an inactive account being reactivated and there is a sync delay.
#
# I will try again in 24 hours
