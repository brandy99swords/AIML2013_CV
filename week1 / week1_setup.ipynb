# %% [markdown]
# <a href="https://colab.research.google.com/github/brandy99swords/AIML2013_CV/blob/main/week1%20/%20week1_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, AIML 2003!")
# Out:
# Hello, AIML 2003!

# %%
# !pip install google-genai

# %%
# !pip install google-genai -q

from google.colab import userdata
from google import genai

client = genai.Client(api_key=userdata.get('GEMINI_API_KEY'))

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="Say hello to AIML 2003 and 2013!"
)
print(response.text)
# Out:
# Hello there, AIML 2003! A nod to the era when chatbots were truly coming into their own, and declarative AI was a fascinating frontier. Thanks for setting the stage and pushing the boundaries of conversational intelligence!
#
# And a big hello to AIML 2013! A decade later, as the AI landscape was rapidly evolving with deep learning beginning its ascent and big data becoming paramount. It's impressive to see AIML's continued adaptability and relevance through the shifting tides of AI.
#
# Greetings to both eras of innovation!

# %% [markdown]
# Note: I had to pay for this. I was getting an error otherwise. It said exhausted resources. Per the Gemini AI chat and other research, this was solely due to the fact that I had set this up for a different class and it was deactivated due to non-use and re-activated after a 2026 update.
#
# Everything I do in this class using this API key will be charged.
#
# I added $10. I hope the coursework does not exceed this amount.
#
# I have never added a Gemini API key to any projects, but have used Google Collab and have utilized other API keys for those projects.
